# %% [markdown]
# <a href="https://colab.research.google.com/github/Rymkulova/Education/blob/main/Blossom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3d4d318-b938-4ae4-821c-17aaa8c3ebf8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3d4d318-b938-4ae4-821c-17aaa8c3ebf8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
first_bl = pd.read_csv('/content/sakura_first_bloom_dates.csv')
first_bl.head()
# Out:
#    Site Name  Currently Being Observed        1953        1954        1955  \
# 0   Wakkanai                      True  1953-05-21  1954-05-17  1955-05-17
# 1      Rumoi                     False  1953-05-08  1954-05-11  1955-05-13
# 2  Asahikawa                      True  1953-05-11  1954-05-13  1955-05-09
# 3   Abashiri                      True  1953-05-24  1954-05-16  1955-05-18
# 4    Sapporo                      True  1953-05-07  1954-05-04  1955-05-11
#
#          1956        1957        1958        1959        1960  ...  \
# 0  1956-05-12  1957-05-18  1958-05-23  1959-05-03  1960-05-19  ...
# 1  1956-05-08  1957-05-10  1958-05-12         NaN         NaN  ...
# 2  1956-05-07  1957-05-09  1958-05-10  1959-05-08  1960-05-13  ...
# 3  1956-05-09         NaN         NaN  1959-05-03         NaN  ...
# 4  1956-05-04  1957-05-09         NaN  1959-05-05  1960-05-05  ...
#
#          2013        2014        2015        2016        2017        2018  \
# ...

# %%
full_bl = pd.read_csv('/content/sakura_full_bloom_dates.csv')
full_bl.head()
# Out:
#    Site Name  Currently Being Observed        1953        1954        1955  \
# 0   Wakkanai                      True  1953-05-30  1954-05-27  1955-05-23
# 1      Rumoi                     False  1953-05-13  1954-05-17  1955-05-16
# 2  Asahikawa                      True  1953-05-16  1954-05-18  1955-05-14
# 3   Abashiri                      True  1953-05-26  1954-05-19  1955-05-20
# 4    Sapporo                      True  1953-05-14  1954-05-08  1955-05-16
#
#          1956        1957        1958        1959        1960  ...  \
# 0  1956-05-14  1957-05-22  1958-05-25  1959-05-12  1960-05-24  ...
# 1  1956-05-14  1957-05-14  1958-05-16         NaN         NaN  ...
# 2  1956-05-13  1957-05-14  1958-05-15  1959-05-13  1960-05-16  ...
# 3  1956-05-13         NaN         NaN  1959-05-07         NaN  ...
# 4  1956-05-09  1957-05-13         NaN  1959-05-10  1960-05-09  ...
#
#          2013        2014        2015        2016        2017        2018  \
# ...

# %%
first_bl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 72 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Site Name                  102 non-null    object
#  1   Currently Being Observed   102 non-null    bool
#  2   1953                       79 non-null     object
#  3   1954                       81 non-null     object
#  4   1955                       82 non-null     object
#  5   1956                       84 non-null     object
#  6   1957                       83 non-null     object
#  7   1958                       83 non-null     object
#  8   1959                       86 non-null     object
#  9   1960                       85 non-null     object
#  10  1961                       86 non-null     object
#  11  1962                       88 non-null     object
#  12  1963                       89 non-null     object
# ...

# %%
first_bl['1953'] = pd.to_datetime(first_bl['1953'])

# %%
full_bl['1953'] = pd.to_datetime(full_bl['1953'])

# %%
first_bl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 72 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Site Name                  102 non-null    object
#  1   Currently Being Observed   102 non-null    bool
#  2   1953                       79 non-null     datetime64[ns]
#  3   1954                       81 non-null     object
#  4   1955                       82 non-null     object
#  5   1956                       84 non-null     object
#  6   1957                       83 non-null     object
#  7   1958                       83 non-null     object
#  8   1959                       86 non-null     object
#  9   1960                       85 non-null     object
#  10  1961                       86 non-null     object
#  11  1962                       88 non-null     object
#  12  1963                       89 non-null     object
# ...

# %%
first_bl['Site Name'].groupby(first_bl['1953'].dt.month).nunique()
# Out:
# 1953
# 1.0     2
# 3.0    23
# 4.0    42
# 5.0    12
# Name: Site Name, dtype: int64

# %%
pd.merge(first_bl, full_bl, how='left')
# Out:
#            Site Name  Currently Being Observed       1953        1954  \
# 0           Wakkanai                      True 1953-05-21  1954-05-17
# 1              Rumoi                     False 1953-05-08  1954-05-11
# 2          Asahikawa                      True 1953-05-11  1954-05-13
# 3           Abashiri                      True 1953-05-24  1954-05-16
# 4            Sapporo                      True 1953-05-07  1954-05-04
# ..               ...                       ...        ...         ...
# 97          Kumejima                     False        NaT         NaN
# 98              Naha                      True        NaT         NaN
# 99              Nago                     False        NaT         NaN
# 100  Iriomote Island                     False        NaT         NaN
# 101  Minamidaitojima                      True        NaT         NaN
#
#            1955        1956        1957        1958        1959        1960  \
# ...

# %%
pd.merge(first_bl, full_bl, how='left', left_on='Site Name', right_on='Site Name')
# Out:
#            Site Name  Currently Being Observed_x     1953_x      1954_x  \
# 0           Wakkanai                        True 1953-05-21  1954-05-17
# 1              Rumoi                       False 1953-05-08  1954-05-11
# 2          Asahikawa                        True 1953-05-11  1954-05-13
# 3           Abashiri                        True 1953-05-24  1954-05-16
# 4            Sapporo                        True 1953-05-07  1954-05-04
# ..               ...                         ...        ...         ...
# 97          Kumejima                       False        NaT         NaN
# 98              Naha                        True        NaT         NaN
# 99              Nago                       False        NaT         NaN
# 100  Iriomote Island                       False        NaT         NaN
# 101  Minamidaitojima                        True        NaT         NaN
#
#          1955_x      1956_x      1957_x      1958_x      1959_x      1960_x  \
# ...

# %%
first_bl['Country'] = 'Japan'

# %%
first_bl.head(1)
# Out:
#   Site Name  Currently Being Observed       1953        1954        1955  \
# 0  Wakkanai                      True 1953-05-21  1954-05-17  1955-05-17
#
#          1956        1957        1958        1959        1960  ...  \
# 0  1956-05-12  1957-05-18  1958-05-23  1959-05-03  1960-05-19  ...
#
#          2014        2015        2016        2017        2018        2019  \
# 0  2014-05-11  2015-05-03  2016-05-13  2017-05-09  2018-05-12  2019-05-07
#
#          2020 30 Year Average 1981-2010                              Notes  \
# 0  2020-05-10                      5 14  Sargent cherry (Prunus sargentii)
#
#   Country
# 0   Japan
#
# [1 rows x 73 columns]

# %%
first_bl.drop(columns='Notes')
# Out:
#            Site Name  Currently Being Observed       1953        1954  \
# 0           Wakkanai                      True 1953-05-21  1954-05-17
# 1              Rumoi                     False 1953-05-08  1954-05-11
# 2          Asahikawa                      True 1953-05-11  1954-05-13
# 3           Abashiri                      True 1953-05-24  1954-05-16
# 4            Sapporo                      True 1953-05-07  1954-05-04
# ..               ...                       ...        ...         ...
# 97          Kumejima                     False        NaT         NaN
# 98              Naha                      True        NaT         NaN
# 99              Nago                     False        NaT         NaN
# 100  Iriomote Island                     False        NaT         NaN
# 101  Minamidaitojima                      True        NaT         NaN
#
#            1955        1956        1957        1958        1959        1960  \
# ...

# %%
first_bl.dropna()
# Out:
#    Site Name  Currently Being Observed       1953        1954        1955  \
# 2  Asahikawa                      True 1953-05-11  1954-05-13  1955-05-09
# 6    Obihiro                      True 1953-05-15  1954-05-07  1955-05-10
#
#          1956        1957        1958        1959        1960  ...  \
# 2  1956-05-07  1957-05-09  1958-05-10  1959-05-08  1960-05-13  ...
# 6  1956-05-05  1957-05-09  1958-05-13  1959-05-01  1960-05-11  ...
#
#          2014        2015        2016        2017        2018        2019  \
# 2  2014-05-02  2015-04-27  2016-05-03  2017-05-03  2018-04-30  2019-05-01
# 6  2014-04-27  2015-04-26  2016-04-30  2017-05-01  2018-04-27  2019-04-28
#
#          2020 30 Year Average 1981-2010                              Notes  \
# 2  2020-05-03                      5  5  Sargent cherry (Prunus sargentii)
# 6  2020-05-02                      5  4  Sargent cherry (Prunus sargentii)
#
#   Country
# 2   Japan
# 6   Japan
#
# [2 rows x 73 columns]

# %%
first_bl.sort_values(by='30 Year Average 1981-2010')
# Out:
#     Site Name  Currently Being Observed       1953        1954        1955  \
# 27    Onahama                     False 1953-04-06  1954-04-01  1955-04-03
# 28     Wajima                     False 1953-04-08  1954-04-05  1955-04-07
# 29     Aikawa                     False 1953-04-11  1954-04-06  1955-04-08
# 85      Fukue                     False 1953-03-26  1954-03-30  1955-03-23
# 34     Takada                     False 1953-04-10  1954-04-04  1955-04-03
# ..        ...                       ...        ...         ...         ...
# 2   Asahikawa                      True 1953-05-11  1954-05-13  1955-05-09
# 9     Muroran                      True 1953-05-10  1954-05-07  1955-05-18
# 3    Abashiri                      True 1953-05-24  1954-05-16  1955-05-18
# 0    Wakkanai                      True 1953-05-21  1954-05-17  1955-05-17
# 7     Kushiro                      True        NaT         NaN         NaN
#
# ...

# %%
def blossom_time(blossom_month):
  if blossom_month <=3.0:
    return 'Early blossom'
  else:
    return 'Later blossom'

# %%
first_bl['Blossom_type'] = first_bl['1953'].dt.month.apply(blossom_time)

# %%
first_bl.head()
# Out:
#    Site Name  Currently Being Observed       1953        1954        1955  \
# 0   Wakkanai                      True 1953-05-21  1954-05-17  1955-05-17
# 1      Rumoi                     False 1953-05-08  1954-05-11  1955-05-13
# 2  Asahikawa                      True 1953-05-11  1954-05-13  1955-05-09
# 3   Abashiri                      True 1953-05-24  1954-05-16  1955-05-18
# 4    Sapporo                      True 1953-05-07  1954-05-04  1955-05-11
#
#          1956        1957        1958        1959        1960  ...  \
# 0  1956-05-12  1957-05-18  1958-05-23  1959-05-03  1960-05-19  ...
# 1  1956-05-08  1957-05-10  1958-05-12         NaN         NaN  ...
# 2  1956-05-07  1957-05-09  1958-05-10  1959-05-08  1960-05-13  ...
# 3  1956-05-09         NaN         NaN  1959-05-03         NaN  ...
# 4  1956-05-04  1957-05-09         NaN  1959-05-05  1960-05-05  ...
#
#          2015        2016        2017        2018        2019        2020  \
# ...
